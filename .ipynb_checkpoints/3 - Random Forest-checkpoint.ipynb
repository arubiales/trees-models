# %% [markdown]
# # Random Forest

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score, f1_score, confusion_matrix, classification_report

# %%
df_football = pd.read_pickle('data/df_data_cleaned.csv')
df_football
# Out:
#                        Name   Age  Overall  Potential  \
# 0                  L. Messi  31.0     94.0       94.0
# 1         Cristiano Ronaldo  33.0     94.0       94.0
# 2                 Neymar Jr  26.0     92.0       93.0
# 3              K. De Bruyne  27.0     91.0       92.0
# 4                 E. Hazard  27.0     91.0       91.0
# 5                 L. Modrić  32.0     91.0       91.0
# 6                 L. Suárez  31.0     91.0       91.0
# 7              Sergio Ramos  32.0     91.0       91.0
# 8            R. Lewandowski  29.0     90.0       90.0
# 9                  T. Kroos  28.0     90.0       90.0
# 10                 D. Godín  32.0     90.0       90.0
# 11              David Silva  32.0     90.0       90.0
# 12                 N. Kanté  27.0     89.0       90.0
# 13                P. Dybala  24.0     89.0       94.0
# 14                  H. Kane  24.0     89.0       91.0
# 15             A. Griezmann  27.0     89.0       90.0
# 16          Sergio Busquets  29.0     89.0       89.0
# 17                E. Cavani  31.0     89.0       89.0
# 18                S. Agüero  30.0     89.0       89.0
# 19             G. Chiellini  33.0     89.0       89.0
# 20                K. Mbappé  19.0     88.0       95.0
# 21                 M. Salah  26.0     88.0       89.0
# 22                 Casemiro  26.0     88.0       90.0
# 23               L. Insigne  27.0     88.0       88.0
# 24                     Isco  26.0     88.0       91.0
# 25               C. Eriksen  26.0     88.0       91.0
# 26                 Coutinho  26.0     88.0       89.0
# 27            P. Aubameyang  29.0     88.0       88.0
# 28               M. Hummels  29.0     88.0       88.0
# 29                  Marcelo  30.0     88.0       88.0
# ...                     ...   ...      ...        ...
# 14713           Y. Uchimura  33.0     48.0       48.0
# 14714              R. Takae  20.0     48.0       63.0
# 14715            S. Adewusi  18.0     48.0       63.0
# 14716             E. Clarke  19.0     48.0       59.0
# 14717            T. Hillman  17.0     48.0       57.0
# 14718             R. Roache  18.0     48.0       69.0
# 14719           J. Williams  17.0     48.0       64.0
# 14720              C. Maher  17.0     48.0       66.0
# 14721               Y. Góez  18.0     48.0       65.0
# 14722             D. Horton  18.0     48.0       55.0
# 14723              E. Tweed  19.0     48.0       59.0
# 14724          Zhang Yufeng  20.0     47.0       64.0
# 14725             C. Ehlich  19.0     47.0       59.0
# 14726            L. Collins  17.0     47.0       62.0
# 14727            A. Kaltner  18.0     47.0       61.0
# 14728            L. Watkins  18.0     47.0       67.0
# 14729  J. Norville-Williams  18.0     47.0       65.0
# 14730             S. Squire  18.0     47.0       64.0
# 14731            N. Fuentes  18.0     47.0       64.0
# 14732            S. Griffin  18.0     47.0       67.0
# 14733           K. Fujikawa  19.0     47.0       61.0
# 14734            D. Holland  18.0     47.0       61.0
# 14735          M. Baldisimo  18.0     47.0       69.0
# 14736              J. Young  18.0     47.0       62.0
# 14737              D. Walsh  18.0     47.0       68.0
# 14738          J. Lundstram  19.0     47.0       65.0
# 14739    N. Christoffersson  19.0     47.0       63.0
# 14740             B. Worman  16.0     47.0       67.0
# 14741        D. Walker-Rice  17.0     47.0       66.0
# 14733           44.0           54.0      10.0        12.0        6.0
# 14734           47.0           38.0      13.0         6.0        9.0
# 14735           49.0           49.0       7.0         7.0        9.0
# 14736           17.0           14.0      11.0        15.0       12.0
# 14737           47.0           53.0       9.0        10.0        9.0
# 14738           48.0           47.0      10.0        13.0        7.0
# 14739           15.0           19.0      10.0         9.0        9.0
# 14740           13.0           11.0       6.0         5.0       10.0
# 14741           25.0           27.0      14.0         6.0       14.0
# 14742           43.0           50.0      10.0        15.0        9.0
#
#        GKPositioning  GKReflexes  Release Clause
# 0               14.0         8.0     226500000.0
# 1               14.0        11.0     127100000.0
# 2               15.0        11.0     228100000.0
# 3               10.0        13.0     196400000.0
# 4                8.0         8.0     172100000.0
# 5               14.0         9.0     137400000.0
# 6               33.0        37.0     164000000.0
# 7                7.0        11.0     104600000.0
# 8                8.0        10.0     127100000.0
# 9                7.0        10.0     156800000.0
# 10               5.0        15.0      90200000.0
# 11               6.0        12.0     111000000.0
# 12               7.0        10.0     121300000.0
# 13               5.0         8.0     153500000.0
# 14              14.0        11.0     160700000.0
# 15              13.0        14.0     165800000.0
# 16               9.0        13.0     105600000.0
# 17              13.0        10.0     111000000.0
# 18              11.0        14.0     119300000.0
# 19               4.0         3.0      44600000.0
# 20              11.0         6.0     166100000.0
# 21              11.0        14.0     137300000.0
# 22              12.0        12.0     126400000.0
# 23               9.0        10.0     105400000.0
# 24              15.0         6.0     156200000.0
# 25               7.0         6.0     141500000.0
# 26              14.0         6.0     147700000.0
# 27               9.0         9.0     112100000.0
# 28               5.0         6.0      75900000.0
# 29               5.0         9.0      88200000.0
# ...              ...         ...             ...
# 14713           15.0        15.0       2500000.0
# 14714           13.0         8.0      11300000.0
# 14715           13.0        12.0      14300000.0
# 14716           12.0         7.0       7800000.0
# 14717           10.0         8.0       7800000.0
# 14718            7.0        12.0      19300000.0
# 14719           11.0         8.0      11900000.0
# 14720            9.0        10.0      10900000.0
# 14721            8.0         6.0      10100000.0
# 14722           14.0        15.0       7800000.0
# 14723            5.0         8.0       8800000.0
# 14724            6.0         8.0      16700000.0
# 14725           15.0        12.0       6600000.0
# 14726           13.0        10.0      14300000.0
# 14727           12.0         8.0      12500000.0
# 14728           10.0         8.0      16500000.0
# 14729           14.0        12.0      11900000.0
# 14730           12.0        13.0      11900000.0
# 14731           12.0        11.0       9900000.0
# 14732            7.0        13.0      15300000.0
# 14733           11.0         8.0      11300000.0
# 14734           10.0        15.0       8800000.0
# 14735           14.0        15.0      17500000.0
# 14736           12.0        11.0      14300000.0
# 14737           11.0        13.0      15300000.0
# 14738            8.0         9.0      14300000.0
# 14739            5.0        12.0      11300000.0
# 14740            6.0        13.0      16500000.0
# 14741            8.0         9.0      14300000.0
# 14742           12.0         9.0      16500000.0
#
# [14743 rows x 76 columns]

# %%
train, test = train_test_split(df_football, train_size=0.75, test_size=0.25)
X_train = train.drop(columns=['Name', 'Club', 'Position', 'Preferred Foot', 'Value'])
y_train = train[['Value']]
X_test = test.drop(columns=['Name', 'Club', 'Position', 'Preferred Foot', 'Value'])
y_test = test[['Value']]

# %% [markdown]
# ## Random Forest
# ![Random forest image](https://miro.medium.com/max/936/1*58f1CZ8M4il0OZYg2oRN4w.png)
# Is almost the same as Decission Tree, but here instead of one tree we a have "N" number of trees. it's one of the best ensemble learning methods. The idea behind this is to combine multiple decision trees to determine the final output, with this our model have more knowledge about our dataset (100 decission trees model are better than 1). If you want to know more about Decission trees go to his section in this repository

# %% [markdown]
# ## Random Forest Regressor
# ### Params
# The majority of the params are the same as Decission Tree Regressor, here we're just going to see the new hyperparameters
# * n_estimators: the numbers of DecissionTrees of our Random Forest
# * Bootsrapt: True/False, if True, the model use train subsamples to build each tree, this help to reduce overfitting and give very good results. If false, the model train all trees with whole dataset. It's strongly recommendet choose the True option
# * oob_score: True/False, is a way to validate Random Forest model. When we take the samples to train the model, the model leaves out some samples in order to validate the training set.
# * Warm_start: it helps to increase the speed of training when you are fitting estimators repeatedly, for example it helps with GridsearCV, or if we want to add new trees to the Random Forest

# %%
rf_reg = RandomForestRegressor(random_state=2019)

rf_reg.fit(X_train, y_train)
predictions = rf_reg.predict(X_test)
print('MAE in train:', mean_absolute_error(rf_reg.predict(X_train), y_train))
print('MSE in train:', np.sqrt(mean_squared_error(rf_reg.predict(X_train), y_train)))
print('MAE in test:', mean_absolute_error(rf_reg.predict(X_test), y_test))
print('RMSE in test:', np.sqrt(mean_squared_error(rf_reg.predict(X_test), y_test)))
# Out:
# C:\Users\alberto.rubiales\miniconda3\envs\Pycharm\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\alberto.rubiales\miniconda3\envs\Pycharm\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# MAE in train: 1687209.0078683188
# MSE in train: 4781322.293865469
# MAE in test: 3992533.9120998373
# RMSE in test: 10632635.1290914

# %% [markdown]
# We can see that wihout param tunning our Random Forest Regressor is in the same error than our Decision Tree Regressor with param tunning. Now let going to use hyperparams

# %%
rf_reg2 = RandomForestRegressor(n_estimators=200, oob_score=True, max_depth=25, 
                                random_state=2019, n_jobs=-1) #set n_jobs in -2 if your computer is not powerfull

rf_reg2.fit(X_train, y_train)
predictions = rf_reg2.predict(X_test)
print('MAE in train:', mean_absolute_error(rf_reg2.predict(X_train), y_train))
print('MSE in train:', np.sqrt(mean_squared_error(rf_reg2.predict(X_train), y_train)))
print('MAE in test:', mean_absolute_error(rf_reg2.predict(X_test), y_test))
print('RMSE in test:', np.sqrt(mean_squared_error(rf_reg2.predict(X_test), y_test)))
# Out:
# C:\Users\alberto.rubiales\miniconda3\envs\Pycharm\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# MAE in train: 1478463.8207002212
# MSE in train: 3922112.655077254
# MAE in test: 3709972.681636176
# RMSE in test: 9789550.577624224

# %% [markdown]
# We have reduce our RMSE in 1M in comparision with our Decision Tree Regressor, Let's see the feature importance now

# %%
pd.DataFrame(rf_reg2.feature_importances_, index=X_train.columns).sort_values(by=0, ascending=False)[:8]
# Out:
#                        0
# Release Clause  0.685678
# Overall         0.099129
# Potential       0.047168
# Wage            0.013090
# Age             0.012588
# StandingTackle  0.005407
# SlidingTackle   0.005174
# Finishing       0.004640

# %% [markdown]
# Wow as in Decision Tree, Release Clause is the most important feature, maybe if we drop this feature, we will obtain better result

# %% [markdown]
# ## Random Forest Classifier

# %%
def age_group_creator(age):
    if age <24:
        return 0 #young
    elif age >= 24 and age < 30:
        return 1 #medium age
    else:
        return 2 #old
        
df_football['age_group'] = df_football.apply(lambda x: age_group_creator(x['Age']), axis=1)
df_football
# Out:
#                        Name   Age  Overall  Potential  \
# 0                  L. Messi  31.0     94.0       94.0
# 1         Cristiano Ronaldo  33.0     94.0       94.0
# 2                 Neymar Jr  26.0     92.0       93.0
# 3              K. De Bruyne  27.0     91.0       92.0
# 4                 E. Hazard  27.0     91.0       91.0
# 5                 L. Modrić  32.0     91.0       91.0
# 6                 L. Suárez  31.0     91.0       91.0
# 7              Sergio Ramos  32.0     91.0       91.0
# 8            R. Lewandowski  29.0     90.0       90.0
# 9                  T. Kroos  28.0     90.0       90.0
# 10                 D. Godín  32.0     90.0       90.0
# 11              David Silva  32.0     90.0       90.0
# 12                 N. Kanté  27.0     89.0       90.0
# 13                P. Dybala  24.0     89.0       94.0
# 14                  H. Kane  24.0     89.0       91.0
# 15             A. Griezmann  27.0     89.0       90.0
# 16          Sergio Busquets  29.0     89.0       89.0
# 17                E. Cavani  31.0     89.0       89.0
# 18                S. Agüero  30.0     89.0       89.0
# 19             G. Chiellini  33.0     89.0       89.0
# 20                K. Mbappé  19.0     88.0       95.0
# 21                 M. Salah  26.0     88.0       89.0
# 22                 Casemiro  26.0     88.0       90.0
# 23               L. Insigne  27.0     88.0       88.0
# 24                     Isco  26.0     88.0       91.0
# 25               C. Eriksen  26.0     88.0       91.0
# 26                 Coutinho  26.0     88.0       89.0
# 27            P. Aubameyang  29.0     88.0       88.0
# 28               M. Hummels  29.0     88.0       88.0
# 29                  Marcelo  30.0     88.0       88.0
# ...                     ...   ...      ...        ...
# 14713           Y. Uchimura  33.0     48.0       48.0
# 14714              R. Takae  20.0     48.0       63.0
# 14715            S. Adewusi  18.0     48.0       63.0
# 14716             E. Clarke  19.0     48.0       59.0
# 14717            T. Hillman  17.0     48.0       57.0
# 14718             R. Roache  18.0     48.0       69.0
# 14719           J. Williams  17.0     48.0       64.0
# 14720              C. Maher  17.0     48.0       66.0
# 14721               Y. Góez  18.0     48.0       65.0
# 14722             D. Horton  18.0     48.0       55.0
# 14723              E. Tweed  19.0     48.0       59.0
# 14724          Zhang Yufeng  20.0     47.0       64.0
# 14725             C. Ehlich  19.0     47.0       59.0
# 14726            L. Collins  17.0     47.0       62.0
# 14727            A. Kaltner  18.0     47.0       61.0
# 14728            L. Watkins  18.0     47.0       67.0
# 14729  J. Norville-Williams  18.0     47.0       65.0
# 14730             S. Squire  18.0     47.0       64.0
# 14731            N. Fuentes  18.0     47.0       64.0
# 14732            S. Griffin  18.0     47.0       67.0
# 14733           K. Fujikawa  19.0     47.0       61.0
# 14734            D. Holland  18.0     47.0       61.0
# 14735          M. Baldisimo  18.0     47.0       69.0
# 14736              J. Young  18.0     47.0       62.0
# 14737              D. Walsh  18.0     47.0       68.0
# 14729          46.0      15.0        13.0        6.0           14.0
# 14730          44.0      11.0        11.0        8.0           12.0
# 14731          48.0       6.0        10.0        6.0           12.0
# 14732          48.0      13.0        14.0       12.0            7.0
# 14733          54.0      10.0        12.0        6.0           11.0
# 14734          38.0      13.0         6.0        9.0           10.0
# 14735          49.0       7.0         7.0        9.0           14.0
# 14736          14.0      11.0        15.0       12.0           12.0
# 14737          53.0       9.0        10.0        9.0           11.0
# 14738          47.0      10.0        13.0        7.0            8.0
# 14739          19.0      10.0         9.0        9.0            5.0
# 14740          11.0       6.0         5.0       10.0            6.0
# 14741          27.0      14.0         6.0       14.0            8.0
# 14742          50.0      10.0        15.0        9.0           12.0
#
#        GKReflexes  Release Clause  age_group
# 0             8.0     226500000.0          2
# 1            11.0     127100000.0          2
# 2            11.0     228100000.0          1
# 3            13.0     196400000.0          1
# 4             8.0     172100000.0          1
# 5             9.0     137400000.0          2
# 6            37.0     164000000.0          2
# 7            11.0     104600000.0          2
# 8            10.0     127100000.0          1
# 9            10.0     156800000.0          1
# 10           15.0      90200000.0          2
# 11           12.0     111000000.0          2
# 12           10.0     121300000.0          1
# 13            8.0     153500000.0          1
# 14           11.0     160700000.0          1
# 15           14.0     165800000.0          1
# 16           13.0     105600000.0          1
# 17           10.0     111000000.0          2
# 18           14.0     119300000.0          2
# 19            3.0      44600000.0          2
# 20            6.0     166100000.0          0
# 21           14.0     137300000.0          1
# 22           12.0     126400000.0          1
# 23           10.0     105400000.0          1
# 24            6.0     156200000.0          1
# 25            6.0     141500000.0          1
# 26            6.0     147700000.0          1
# 27            9.0     112100000.0          1
# 28            6.0      75900000.0          1
# 29            9.0      88200000.0          2
# ...           ...             ...        ...
# 14713        15.0       2500000.0          2
# 14714         8.0      11300000.0          0
# 14715        12.0      14300000.0          0
# 14716         7.0       7800000.0          0
# 14717         8.0       7800000.0          0
# 14718        12.0      19300000.0          0
# 14719         8.0      11900000.0          0
# 14720        10.0      10900000.0          0
# 14721         6.0      10100000.0          0
# 14722        15.0       7800000.0          0
# 14723         8.0       8800000.0          0
# 14724         8.0      16700000.0          0
# 14725        12.0       6600000.0          0
# 14726        10.0      14300000.0          0
# 14727         8.0      12500000.0          0
# 14728         8.0      16500000.0          0
# 14729        12.0      11900000.0          0
# 14730        13.0      11900000.0          0
# 14731        11.0       9900000.0          0
# 14732        13.0      15300000.0          0
# 14733         8.0      11300000.0          0
# 14734        15.0       8800000.0          0
# 14735        15.0      17500000.0          0
# 14736        11.0      14300000.0          0
# 14737        13.0      15300000.0          0
# 14738         9.0      14300000.0          0
# 14739        12.0      11300000.0          0
# 14740        13.0      16500000.0          0
# 14741         9.0      14300000.0          0
# 14742         9.0      16500000.0          0
#
# [14743 rows x 77 columns]

# %%
train, test = train_test_split(df_football, train_size=0.75, test_size=0.25)
X_train = train.drop(columns=['Name', 'Club', 'Position', 'Preferred Foot', 'Age', 'age_group'])
y_train = train[['age_group']]
X_test = test.drop(columns=['Name', 'Club', 'Position', 'Preferred Foot', 'Age', 'age_group'])
y_test = test[['age_group']]

# %% [markdown]
# Whithout param tunning

# %%
#instance
rf_class = RandomForestClassifier()

#train
rf_class.fit(X_train, y_train)

#train preds
preds_train = rf_class.predict(X_train)

#metrics classifications in train
print('CLASSIFICATION IN TRAIN')
print()
print('CONFUSION MATRIX:\n', confusion_matrix(preds_train, y_train))
print()
print('F1 SCORE:\n', f1_score(preds_train, y_train, average='micro'))
print()
print('CLASSIFICATION REPORT\n',classification_report(preds_train, y_train))
# Out:
# C:\Users\alberto.rubiales\miniconda3\envs\Pycharm\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\alberto.rubiales\miniconda3\envs\Pycharm\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """
# CLASSIFICATION IN TRAIN
#
# CONFUSION MATRIX:
#  [[4431   15    3]
#  [   8 4497   50]
#  [   0    4 2049]]
#
# F1 SCORE:
#  0.9927647644026408
#
# CLASSIFICATION REPORT
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4449
#            1       1.00      0.99      0.99      4555
#            2       0.97      1.00      0.99      2053
#
#     accuracy                           0.99     11057
#    macro avg       0.99      0.99      0.99     11057
# weighted avg       0.99      0.99      0.99     11057

# %%
#Classification in test
preds_trest = rf_class.predict(X_test)

#metrics classifications in train
print('CLASSIFICATION IN TEST')
print()
print('CONFUSION MATRIX:\n', confusion_matrix(preds_trest, y_test))
print()
print('F1 SCORE:\n', f1_score(preds_trest, y_test, average='micro'))
print()
print('CLASSIFICATION REPORT\n',classification_report(preds_trest, y_test))
# Out:
# CLASSIFICATION IN TEST
#
# CONFUSION MATRIX:
#  [[1248  213    8]
#  [ 197 1187  395]
#  [   4  118  316]]
#
# F1 SCORE:
#  0.74633749321758
#
# CLASSIFICATION REPORT
#                precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86      1469
#            1       0.78      0.67      0.72      1779
#            2       0.44      0.72      0.55       438
#
#     accuracy                           0.75      3686
#    macro avg       0.69      0.75      0.71      3686
# weighted avg       0.77      0.75      0.75      3686

# %% [markdown]
# With param tunning

# %%
#instance
rf_class2 = RandomForestClassifier(criterion='entropy', n_estimators=400, max_features=25, class_weight='balanced_subsample',
                                   n_jobs=-1, oob_score=True)

#train
rf_class2.fit(X_train, y_train)

#train preds
preds_train = rf_class2.predict(X_train)

#metrics classifications in train
print('CLASSIFICATION IN TRAIN')
print()
print('CONFUSION MATRIX:\n', confusion_matrix(preds_train, y_train))
print()
print('F1 SCORE:\n', f1_score(preds_train, y_train, average='micro'))
print()
print('CLASSIFICATION REPORT\n',classification_report(preds_train, y_train))
# Out:
# C:\Users\alberto.rubiales\miniconda3\envs\Pycharm\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# CLASSIFICATION IN TRAIN
#
# CONFUSION MATRIX:
#  [[4439    0    0]
#  [   0 4516    0]
#  [   0    0 2102]]
#
# F1 SCORE:
#  1.0
#
# CLASSIFICATION REPORT
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4439
#            1       1.00      1.00      1.00      4516
#            2       1.00      1.00      1.00      2102
#
#     accuracy                           1.00     11057
#    macro avg       1.00      1.00      1.00     11057
# weighted avg       1.00      1.00      1.00     11057

# %%
#Classification in test
preds_trest = rf_class2.predict(X_test)

#metrics classifications in train
print('CLASSIFICATION IN TEST')
print()
print('CONFUSION MATRIX:\n', confusion_matrix(preds_trest, y_test))
print()
print('F1 SCORE:\n', f1_score(preds_trest, y_test, average='micro'))
print()
print('CLASSIFICATION REPORT\n',classification_report(preds_trest, y_test))
# Out:
# CLASSIFICATION IN TEST
#
# CONFUSION MATRIX:
#  [[1318  103    0]
#  [ 131 1368  248]
#  [   0   47  471]]
#
# F1 SCORE:
#  0.8564839934888768
#
# CLASSIFICATION REPORT
#                precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92      1421
#            1       0.90      0.78      0.84      1747
#            2       0.66      0.91      0.76       518
#
#     accuracy                           0.86      3686
#    macro avg       0.82      0.87      0.84      3686
# weighted avg       0.87      0.86      0.86      3686

# %%
pd.DataFrame(rf_class2.feature_importances_, index=X_train.columns).sort_values(by=0, ascending=False)[:8]
# Out:
#                        0
# Potential       0.197758
# Overall         0.141178
# Value           0.060461
# Release Clause  0.046315
# Reactions       0.040503
# Composure       0.038533
# SprintSpeed     0.024189
# Special         0.021489

# %%
#See our 200 trees
rf_class2.estimators_
# Out:
# [DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1035469788, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1887871593, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=21301838, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1731813827, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1654431266, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1056223065, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=947385640, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1105197340, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1977595482, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=853770177, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=626242163, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=319303197, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1813388054, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=80075872, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1990975627, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=768410855, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=853442157, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=744017850, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1599624592, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=51542320, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=173511526, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=138788694, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=764618626, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=93133258, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1117262686, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=737878085, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=24845918, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=144534309, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=44092818, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=622879503, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1242171869, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1011698050, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1651498966, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1532885940, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=924258796, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1930638433, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=422267900, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1934405838, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1733474899, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=504892114, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=735103464, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=981832270, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1633949953, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1394681804, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=758762810, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=2088249753, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1783610227, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1873588219, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1250222669, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=822842253, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1677196797, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=604617706, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=80351576, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=810740985, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1314062013, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1568569054, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=27676900, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=52830710, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=2021558209, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=166414886, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=966497704, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=365622139, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1016868767, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1010779921, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=776772393, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=990503128, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=9852915, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1390638475, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=347502479, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1594512367, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1144358939, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1132939315, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1029167137, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=869293595, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1894328096, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1495974641, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1215247356, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=125626979, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=337682528, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=787470613, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1324832616, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1961563652, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=2041162927, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=2076970899, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1776853216, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=2072683732, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=424000803, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1181073084, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=193482170, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=734461, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1470933684, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=265624355, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=646838569, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1024239161, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1090732832, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=2060350534, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=870276010, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1923659626, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=810232951, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=123036595, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1260964364, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=397340903, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=425615909, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=124425010, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1798246702, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=110715634, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1485777973, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=2001145522, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=655851021, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1866774755, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1841838212, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=222750126, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1577243813, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=2067411147, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
# ...
#                         random_state=226958088, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=390061291, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1253244059, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1485395540, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=488608760, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=432048478, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1583808904, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1970724917, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=16217225, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1887684648, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=900191849, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1644280179, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1711865261, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1043031588, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1460483895, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=107227878, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=921268033, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=780577970, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=663280185, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=389010676, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=969899315, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1091248069, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=217189549, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=550783718, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=184583873, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=996062855, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=456769942, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1788095798, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1181434206, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1455419756, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=776144056, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=597258780, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1787498547, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=982762653, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1965030554, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=998261658, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1104216064, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1448740424, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features=25, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=337680107, splitter='best')]

# %% [markdown]
# Our Random Forest Classifier have the same accuracy as our Decision Tree Classifier, This shows us that there are no better models than others. It all depends on our dataset and the types of data we're dealing with.
